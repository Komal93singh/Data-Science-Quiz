# %% [markdown]
# # QUIZ : NLP Assessment
# ---

# %% [markdown]
# ###  Q1. What does NLP stand for?
# 1. Neural Language Processing
# 2. Natural Learning Process
# 3. Natural language Processing
# 4. Neural Learning Protocol

# %% [markdown]
# The correct answer is:
#
# **3. Natural Language Processing**

# %% [markdown]
# ### Q2. Which of the following is NOT a key concept in NLP?
# 1. Tokenization
# 2. Part-of-Speech Tagging
# 3. Regression Analysis
# 4. Named Entity Recongnition

# %% [markdown]
# The correct answer is:
#
# **3. Regression Analysis**
#
# (It's a statistical method, not a core NLP concept.)

# %% [markdown]
# ### Q3. What is the primary purpose of Named Entity Recognition (NER)?
# 1. To translate text from one language to another
# 2. To identity and classify entities like names, locations and organizations
# 3. To summarize long documents
# 4. To detect sentiment in Text

# %% [markdown]
# The correct answer is:
#
# **2. To identify and classify entities like names, locations, and organizations**

# %% [markdown]
# ### Q4. Which of the following is a common use case of NLP?
# 1. Image Classification
# 2. Sentiment Analysis
# 3. Linear Regression
# 4. Clustering

# %% [markdown]
# The correct answer is:
#
# **2. Sentiment Analysis**

# %% [markdown]
# ### Q5. What does a language model in NLP primarily do?
# 1. Classifies image
# 2. Predicts the next word in a sequence
# 3. Detects outliers in data
# 4. Segments customers into groups

# %% [markdown]
# The correct answer is:
#
# **2. Predicts the next word in a sequence**

# %% [markdown]
# ### Q6. Which of the following is an example of a speech recognition application?
# 1. Google Translate
# 2. Siri
# 3. Excel
# 4. Photoshop

# %% [markdown]
# The correct answer is:
#
# **2. Siri**

# %% [markdown]
# ### Q7. Which technique is used in NLP to break down text into individual words or phrases?
# 1. Lemmatization
# 2. Tokenization
# 3. Parsing
# 4. Clustering

# %% [markdown]
# The correct answer is:
#
# **2. Tokenization**

# %% [markdown]
# ### 8. In sentiment analysis, what is the main goal?
# 1. To summarize text
# 2. To identify the sentiment as positive, negative or neutral
# 3. To classify entities
# 4. To translate languages

# %% [markdown]
# The correct answer is:
#
# **2. To identify the sentiment as positive, negative, or neutral**

# %% [markdown]
# ### Q9. Which of the following is an NLP task that involves understanding the grammatical structure of sentences?
# 1. Tokenization
# 2. Syntax and Parsing
# 3. Word Embedding
# 4. Named Entity Recognition

# %% [markdown]
# The correct answer is:
#
# **2. Syntax and Parsing**

# %% [markdown]
# ### Q10. Which model is commonly used for machine translation?
# 1. GPT
# 2. Word2Vec
# 3. BERT
# 4. Google Translate

# %% [markdown]
# The best answer here is:
#
# **4. Google Translate**
#
# (Since Google Translate is a widely used machine translation system. However, among models, Transformer-based models like those behind Google Translate are common.)

# %% [markdown]
# ### Q11. What is the difference between stemming and lemmatization in NLP?
# 1. Stemming uses linguistic rules, while lemmatization removes affixes
# 2. Stemming removes affixes, while lemmatization uses linguistic rules
# 3. Both are the same
# 4. Stemming adds affixs, while lemmatization removes them

# %% [markdown]
# The correct answer is:
#
# **2. Stemming removes affixes, while lemmatization uses linguistic rules**

# %% [markdown]
# ### Q12. WHich of the following is an advantage of using NLP in chatbots and virtual assistants?
# 1. Better image recognition
# 2. Enhanced understanding of user queries in natural language
# 3. Faster numerical calculations
# 4. Improved memory storage

# %% [markdown]
# The correct answer is:
#
# **2. Enhanced understanding of user queries in natural language**

# %% [markdown]
# ### Q13. Which language model revolutionized NLP with its ability to generate coherent text?
# 1. RNN
# 2. Word2Vec
# 3. BERT
# 4. GPT

# %% [markdown]
# The correct answer is:
#
# **4. GPT**

# %% [markdown]
# ### Q14. What is the main function of a Question Answering (Q system in NLP)?
# 1. To generate questions for quizzes
# 2. To classify text into categories
# 3. To provide accurate answers to user queries
# 4. To cluster similar documents

# %% [markdown]
# The correct answer is:
#
# **3. To provide accurate answers to user queries**

# %% [markdown]
# ### Q15. Which NLP task involves classifying text into predefined categories like spam detection or topic categorization?
# 1. Text Classification
# 2. Named Entity Recognition
# 3. Sentiment Analysis
# 4. Language Modeling

# %% [markdown]
# The correct answer is:
#
# **1. Text Classification**

# %% [markdown]
# ### Q16. What is the significance of historical background and evolution in NLP?
# 1. It helps in understanding the future trends of image processing
# 2. It provides insights into how NLP techniques have evolved and improved over time
# 3. It explains how to perform linear regression
# 4. It describes the history of computer hardware

# %% [markdown]
# The correct answer is:
#
# **2. It provides insights into how NLP techniques have evolved and improved over time**

# %% [markdown]
# ### Q17. Which of the following is NOT a typical use case for NLP?
# 1. Speech Recognition
# 2. Image Segmentation
# 3. Text Summarization
# 4. Opinion Mining

# %% [markdown]
# The correct answer is:
#
# **2. Image Segmentation**

# %% [markdown]
# ### 18. Which NLP technique is used to represent words as vectors in a continuous vector space?
# 1. Syntax Parsing
# 2. Word Embeddings
# 3. Sentiment Analysis
# 4. NER

# %% [markdown]
# The correct answer is:
#
# **2. Word Embeddings**

# %% [markdown]
# ### Q19. What does the term "token" refer to in NLP?
# 1. A piece of hardware
# 2. An individual word or phrase in the text
# 3. A language model
# 4. A grammatical rule

# %% [markdown]
# The correct answer is:
#
# **2. An individual word or phrase in the text**

# %% [markdown]
# ### Q20. Which application would most likely require the use of Document Clustering?
# 1. Grouping similar news articles together
# 2. Translating documents from one language to another
# 3. Detecting spam in emails
# 4. Generating summaries for long texts

# %% [markdown]
# The correct answer is:
#
# **1. Grouping similar news articles together**

# %% [markdown]
# ### Q21. Which statistical method was pivotal in the shift from rule-based to machine learning approaches in NLP during the 1990s?
# 1. Support Vector Machines (SVMs)
# 2. Hidden Markov Models (HMMs)
# 3. Decision Trees
# 4. Neural Networks

# %% [markdown]
# The correct answer is:
#
# **2. Hidden Markov Models (HMMs)**

# %% [markdown]
# ### Q22. In Named Entity Recognition (NER), which challenge is commonly faced when classifying entities?
# 1. Identifying the correct part-of-speech tags
# 2. Differentiating between similar named entities in context
# 3. Tokenizing the text correctly
# 4. Generating natural language text

# %% [markdown]
# The correct answer is:
#
# **2. Differentiating between similar named entities in context**

# %% [markdown]
# ### Q23. Which deep learning architecture is most associated with significant advances in NLP, particularly in language models like BERT and GPT?
# 1. Recurrent Neural Networks (RNNs)
# 2. Convolutional Neural Networks (CNNs)
# 3. Transformers
# 4. Feedforward Neural Networks

# %% [markdown]
# The correct answer is:
#
# **3. Transformers**

# %% [markdown]
# ### Q24. What is the primary advantages of using transformers in NLP over traditional RNNs?
# 1. TRansformers are better at handling large sequence and capturing long-range dependencies
# 2. Transformers are easier to interpret
# 3. RNNs are better for parallel processing
# 4. RNNs are more computationally efficient

# %% [markdown]
# The correct answer is:
#
# **1. Transformers are better at handling large sequences and capturing long-range dependencies**

# %% [markdown]
# ### Q25. Which challenges in Machine Translation is best addressed by modern neural network-based approaches?
# 1. Understanding idiomatic expressions
# 2. Tokenizing sentences
# 3. Part-of-Speech tagging
# 4. Named Entity Recognition

# %% [markdown]
# The correct answer is:
#
# **1. Understanding idiomatic expressions**

# %% [markdown]
# ### Q26. Which term best describes the process of converting a complex sentence into a simpler structure while retaining its meaning?
# 1. Lemmatization
# 2. Stemming
# 3. Text Simplification
# 4. Text Summarization

# %% [markdown]
# The correct answer is:
#
# **3. Text Simplification**

# %% [markdown]
# ### Q27. WHat was one of the main limitations of early rule-based NLP systems?
# 1. They were too flexible
# 2. They relied heavily on handcrafted rules and could not generalize well
# 3. They could easily adapt to new languages
# 4. They perfomed better than machine learning-based models

# %% [markdown]
# The correct answer is:
#
# **2. They relied heavily on handcrafted rules and could not generalize well**

# %% [markdown]
# ### Q28. Which of the following tasks is typically more challenging in NLP and requires sophisticated models?
# 1. Tokenization
# 2. Sentiment Analysis
# 3. Named Entity Recognition
# 4. Language Generation

# %% [markdown]
# The correct answer is:
#
# **4. Language Generation**

# %% [markdown]
# ### Q29. Which NLP model introduced the concept of attention mechanisms, leading to major advancements in the field?
# 1. RNN
# 2. Transformer
# 3. Word2Vec
# 4. BERT

# %% [markdown]
# The correct answer is:
#
# **2. Transformer**

# %% [markdown]
# ### Q30. Which NLP application would require both NER and sentiment analysis to work together?
# 1. Analyzing customer feedback to identify key issues and overall sentiment
# 2. Translating a document from English to French
# 3. Classifying emails as spam or not spam
# 4. Generating automatic summaries of news articles

# %% [markdown]
# The correct answer is:
#
# **1. Analyzing customer feedback to identify key issues and overall sentiment**
