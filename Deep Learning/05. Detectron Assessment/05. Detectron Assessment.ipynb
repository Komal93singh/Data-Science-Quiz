# %% [markdown]
# # Quiz : Detectron Assessment
# ---

# %% [markdown]
# ### Q1. What is the purpose of the "Model Zoo" in Detectron2?
# 1. To visualize models
# 2. To provide pre-trained models for quick use
# 3. To store training logs
# 4. To configure custom datasets

# %% [markdown]
# The purpose of the **"Model Zoo"** in Detectron2 is:
#
# **2. To provide pre-trained models for quick use**

# %% [markdown]
# ### Q2. Which of the following operations can you perform using Detectronn2's Visualizer class?
# 1. Apply augmentations
# 2. Draw predictions on an image
# 3. Save models to disk
# 4. Perform model evaluation

# %% [markdown]
# The correct answer is:
#
# **2. Draw predictions on an image**

# %% [markdown]
# ### Q3. Which of the following describes the "data loader" in Detectron2?
# 1. Loads models into memory
# 2. Loads datasets in batches for training
# 3. Loads images onto a webpage
# 4. Loads GPU memory

# %% [markdown]
# The correct answer is:
#
# **2. Loads datasets in batches for training**

# %% [markdown]
# ### Q4. Which of the following is a popular evaluation metric used in Detectron2?
# 1. Accuracy
# 2. Mean Squared Error (MSE)
# 3. Mean Average Precision (mAP)
# 4. Root Mean Square Error (RMSE)

# %% [markdown]
# The correct answer is:
#
# **3. Mean Average Precision (mAP)**

# %% [markdown]
# ### Q5. What is the role of the torchvision package in Detectron2?
# 1. For configuring datasets
# 2. For implementing CNN models
# 3. For image transformations and augmentations
# 4. For computing loss functions

# %% [markdown]
# The correct answer is:
#
# **3. For image transformations and augmentations**

# %% [markdown]
# ### Q6. How do you visualize model predictions using Detectron2?
# 1. visualize_predictions()
# 2. predict. Visualize()
# 3. Visualizer class
# 4. model.show_predictions()

# %% [markdown]
# The correct answer is:
#
# **3. Visualizer class**

# %% [markdown]
# ### Q7. What does the Mask R-CNN model in Detectron2 specifically add on top of Faster R-CNN?
# 1. A classification head
# 2. A segmentation head
# 3. A bounding box regression head
# 4. A keypoint detection head

# %% [markdown]
# The correct answer is:
#
# **2. A segmentation head**

# %% [markdown]
# ### Q8. What is the default backbone architecture used in many Detectron2 models?
# 1. VGG-16
# 2. MobileNet
# 3. ResNet
# 4. EfficientNet

# %% [markdown]
# The correct answer is:
#
# **3. ResNet**

# %% [markdown]
# ### Q9. Which type of learning rate scheduler is commonly used in Detectron2?
# 1. Step LR
# 2. Linear LR
# 3. Warmup LR
# 4. Cyclic LR

# %% [markdown]
# The correct answer is:
#
# **3. Warmup LR**

# %% [markdown]
# ### Q10. In Detectron2, what is the role of the DatasetCatalog?
# 1. To register new datasets
# 2. To load pre-trained models
# 3. To visualize data samples
# 4. To define a training loop

# %% [markdown]
# The correct answer is:
#
# **1. To register new datasets**

# %% [markdown]
# ### Q11. Which of the following is NOT a model architecture available in Detectron2's Model Zoo?
# 1. Faster R-CNN
# 2. Mask R-CNN
# 3. YOLO v4
# 4. RetinaNet

# %% [markdown]
# The correct answer is:
#
# **3. YOLO v4**

# %% [markdown]
# ### Q12. What does the cfg object represent in Detectron2?
# 1. Model parameters
# 2. Configuration object for models and datasets
# 3. Loss function
# 4. Pre-trained weights

# %% [markdown]
# The correct answer is:
#
# **2. Configuration object for models and datasets**

# %% [markdown]
# ### Q13. Which command is used to train a model in Detectron2?
# 1. detectron2_train
# 2. mode.fit()
# 3. trainer. Train()
# 4. train_detector()

# %% [markdown]
# The correct answer is:
#
# **3. trainer.train()**

# %% [markdown]
# ### Q14. What does ROI stand for in Detectron2?
# 1. Region of Interest
# 2. Range of Intensity
# 3. Return on Investment
# 4. Rescale Output Image

# %% [markdown]
# The correct answer is:
#
# **1. Region of Interest**

# %% [markdown]
# ### Q15. What is Detectron2 primarily used for?
# 1. Natural language processing
# 2. Image classification
# 3. Object detection and segmentation
# 4. Audio processing

# %% [markdown]
# The correct answer is:
#
# **3. Object detection and segmentation**

# %% [markdown]
# ### Q16. Which dataset is commonly used with Detectron2 for object detection?
# 1. MNIST
# 2. CIFAR-10
# 3. COCO
# 4. ImageNet

# %% [markdown]
# The correct answer is:
#
# **3. COCO**

# %% [markdown]
# ### Q17. What does the term "instance segmentation" mean in Detectron2?
# 1. Detecting objects in video frames
# 2. Classifying images into categories
# 3. Detecting and segmenting individual objects within an image
# 4. Detecting edges in images

# %% [markdown]
# The correct answer is:
#
# **3. Detecting and segmenting individual objects within an image**

# %% [markdown]
# ### Q18. Which of the following tasks can be performed by Detectron2?
# 1. Object detection
# 2. Semantic segmentation
# 3. Instance segmentation
# 4. All of the above

# %% [markdown]
# The correct answer is:
#
# **4. All of the above**

# %% [markdown]
# ### Q19. WHat is the primary input to a Detectron model?
# 1. Audio
# 2. Text
# 3. Images
# 4. Videos

# %% [markdown]
# The correct answer is:
#
# **3. Images**

# %% [markdown]
# ### Q20. Which of the following is a feature of Detectron2?
# 1. Model Zoo with pre-trained models
# 2. Support for video processing
# 3. In-built data augmentation
# 4. All of the above

# %% [markdown]
# The correct answer is:
#
# **4. All of the above**

# %% [markdown]
# ### Q21. Detectron2 is built on top of which deep learning framework?
# 1. TensorFlow
# 2. PyTorch
# 3. Keras
# 4. Caffe

# %% [markdown]
# The correct answer is:
#
# **2. PyTorch**

# %% [markdown]
# ### Q22. Which company developed Detectron2?
# 1. Microsoft
# 2. Google
# 3. Meta (formerly Facebook)
# 4. IBM

# %% [markdown]
# The correct answer is:
#
# **3. Meta (formerly Facebook)**

# %% [markdown]
# ### Q23. Which of the following datasets is supported by default in Detectron2?
# 1. Pascal VOC
# 2. CIFAR-100
# 3. COCO
# 4. All of the above

# %% [markdown]
# The correct answer is:
#
# **3. COCO**

# %% [markdown]
# ### Q24. Which of the following APIs is provided by Detectron2 for inference?
# 1. DefaultPredictor
# 2. Predict()
# 3. InferenceEngine
# 4. ModelPredictor

# %% [markdown]
# The correct answer is:
#
# **1. DefaultPredictor**

# %% [markdown]
# ### Q25. What is Detectron2's cfg.merge_from_file() used for?
# 1. Loading a pre-trained model
# 2. Merging two images
# 3. Merging configuration from a config file
# 4. Merging two datasets

# %% [markdown]
# The correct answer is:
#
# **3. Merging configuration from a config file**

# %% [markdown]
# ### Q26. Which of the following frameworks can you easily integrate with Detectron2 for deployment?
# 1. ONNX
# 2. TensorFlow Lite
# 3. PyTorch
# 4. All of the above

# %% [markdown]
# The correct answer is:
#
# **1. ONNX**

# %% [markdown]
# ### Q27. Which of the following formats are supported for annotations in Detectron2?
# 1. Pascal VOC XML
# 2. COCO JSON
# 3. LabelMe JSON
# 4. All of the above

# %% [markdown]
# The correct answer is:
#
# **4. All of the above**
